# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final.csv')

# %%
df.iloc[0,:]
# Out:
# Unnamed: 0                                                                    0
# Id                                         1d604da9-9a81-4ba9-80c2-de3375d59b40
# MARITAL                                                                       M
# RACE                                                                      white
# ETHNICITY                                                              hispanic
# GENDER                                                                        M
# BIRTHPLACE                                     Marigot  Saint Andrew Parish  DM
# HEALTHCARE_EXPENSES                                                   271227.08
# HEALTHCARE_COVERAGE                                                     1334.88
# Age                                                                          32
# Alive                                                                         1
# ALLERGY_ENCOUNTER                                                             0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER',
#        'BIRTHPLACE', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'Age',
#        'Alive', 'ALLERGY_ENCOUNTER', 'ALLERGY_CODE', 'Allergy_Time',
#        'Careplan_CODE', 'Careplan_REASONCODE', 'Careplan_Time',
#        'Condition_CODE', 'Condition_DESCRIPTION', 'Condition_Time',
#        'Device_CODE', 'Device_UDI', 'Device_Time', 'ORGANIZATION', 'PROVIDER',
#        'PAYER', 'ENCOUNTERCLASS', 'ENCOUNTERCODE', 'BASE_ENCOUNTER_COST',
#        'ENCOUNTER_TOTAL_CLAIM_COST', 'ENCOUNTER_PAYER_COVERAGE',
#        'Encounter_Time', 'IMAGING_BODYSITE_CODE', 'IMAGING_MODALITY_CODE',
#        'IMAGING_SOP_CODE', 'Immunization_Code', 'Immunization_BASE_COST',
#        'MEDICATION_CODE', 'Medicine_DESCRIPTION', 'MEDICATION_BASE_COST',
#        'MEDICATION_PAYER_COVERAGE', 'MEDICATION_DISPENSES',
#        'MEDICATION_TOTALCOST', 'MEDICATION_REASONCODE', 'Medication_Time',
# ...

# %%
df.drop(['ALLERGY_ENCOUNTER','ALLERGY_CODE','Allergy_Time','Careplan_CODE', 'Careplan_REASONCODE', 'Careplan_Time','Device_CODE', 'Device_UDI',
       'Device_Time','ENCOUNTERCODE','IMAGING_BODYSITE_CODE','IMAGING_MODALITY_CODE', 'IMAGING_SOP_CODE', 'Immunization_Code','Immunization_BASE_COST',
       'OBSERVATION_CODE', 'OBSERVATION_VALUE', 'OBSERVATION_UNITS'],axis = 1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0                                    Id MARITAL   RACE  \
# 0              0  1d604da9-9a81-4ba9-80c2-de3375d59b40       M  white
# 1              1  034e9e3b-2def-4559-bb2a-7850888ae060       M  white
# 2              2  10339b10-3cd1-4ac3-ac13-ec26728cb592       M  white
# 3              3  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae       M  white
# 4              4  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a       0  white
# ...          ...                                   ...     ...    ...
# 1167        1167  023a7d29-32b3-4db5-89c8-b88bd7582ec0       M  asian
# 1168        1168  1fc8dafd-90e5-44d6-9179-81156c0ea083       S  white
# 1169        1169  6d048a56-edb8-4f29-891d-7a84d75a8e78       S  white
# 1170        1170  fca3178e-fb68-41c3-8598-702d3ca68b96       M  white
# 1171        1171  fc817953-cc8b-45db-9c85-7c0ced8fa90d       M  white
#
#         ETHNICITY GENDER                        BIRTHPLACE  \
# 0        hispanic      M  Marigot  Saint Andrew Parish  DM
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER',
#        'BIRTHPLACE', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'Age',
#        'Alive', 'Condition_CODE', 'Condition_DESCRIPTION', 'Condition_Time',
#        'ORGANIZATION', 'PROVIDER', 'PAYER', 'ENCOUNTERCLASS',
#        'BASE_ENCOUNTER_COST', 'ENCOUNTER_TOTAL_CLAIM_COST',
#        'ENCOUNTER_PAYER_COVERAGE', 'Encounter_Time', 'MEDICATION_CODE',
#        'Medicine_DESCRIPTION', 'MEDICATION_BASE_COST',
#        'MEDICATION_PAYER_COVERAGE', 'MEDICATION_DISPENSES',
#        'MEDICATION_TOTALCOST', 'MEDICATION_REASONCODE', 'Medication_Time',
#        'PROCEDURE_CODE', 'Procedure_DESCRIPTION', 'PROCEDURE_BASE_COST',
#        'PROCEDURE_REASONCODE'],
#       dtype='object')

# %%
df.iloc[0,:]
# Out:
# Unnamed: 0                                                                    0
# Id                                         1d604da9-9a81-4ba9-80c2-de3375d59b40
# MARITAL                                                                       M
# RACE                                                                      white
# ETHNICITY                                                              hispanic
# GENDER                                                                        M
# BIRTHPLACE                                     Marigot  Saint Andrew Parish  DM
# HEALTHCARE_EXPENSES                                                   271227.08
# HEALTHCARE_COVERAGE                                                     1334.88
# Age                                                                          32
# Alive                                                                         1
# Condition_CODE                                                      [444814009]
# ...

# %%
df['adherence'] = 0

# %%
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_rows',None)

# %%
df.drop(['ORGANIZATION','PROVIDER','PAYER'],axis=1,inplace=True)

# %%
for i in range(len(df)):
    df.adherence[i] = np.random.randint(0,2)
# Out:
# /tmp/ipykernel_26419/1994365407.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.adherence[i] = np.random.randint(0,2)

# %%
df.adherence.value_counts()
# Out:
# 0    598
# 1    574
# Name: adherence, dtype: int64

# %%
df.to_csv('act.csv')
